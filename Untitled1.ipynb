# %% [markdown]
# ## Update
# ### Following features are added:
# 1. vectors will be reinitialized at every new title
# 2. vectors will be centered according to the first vector of this title

# %% [markdown]
# ### Class DATA:
# An object that wraps around an dataset extracted from Wikipedia using specific format
# * **`DATA.buildCorpora(text_columns)`** extract unique words from text_columns
# * **`loadWordVectors

# %%
import importlib
importlib.reload(DATA)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d703acca1734> in <module>()
#       1 import importlib
# ----> 2 importlib.reload(DATA)
#
# /usr/lib/python3.5/importlib/__init__.py in reload(module)
#     137     """
#     138     if not module or not isinstance(module, types.ModuleType):
# --> 139         raise TypeError("reload() argument must be module")
#     140     try:
#     141         name = module.__spec__.name
#
# TypeError: reload() argument must be module

# %%
# %%time
D = DATA(data)
# D.buildCorpora(['Added','Deleted'])
D.loadWordVectors('test__wordvecs.txt')
D.computeConversationVectors()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# NameError: name 'data' is not defined

# %%
D.to_csv('/home/ubuntu/wikipedia/Visualization/test__output.csv')

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/wikipedia/Visualization/AllCompared.jpg', retina=True)

# %%
from IPython.display import Image
Image(filename='/home/ubuntu/wikipedia/Visualization/wordsVecTSNE.jpg', retina=True)

# %% [markdown]
# Randomization:
# 1. sentence order
# 2. replace the word with a random one (with dictionary)
# 3. another dataset
# 4. nearest neighbor query

# %%
import pandas as pd
import numpy as np
test__file = '/home/ubuntu/wikipedia/DATA/OUTFILE/predicted_enwiki-20161201-pages-meta-history11.xml-p003046514p003201200.7z.tsv'
data = pd.read_csv(test__file, sep='\t')
